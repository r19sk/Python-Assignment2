# %%
print("Hello")
# Out:
# Hello

# %%
print ("Hello \
        python")
# Out:
# Hello         python

# %%
print (""" . (＼_／)
 ٩(◍•౪•◍)۶✧˖° """)
# Out:
#  . (＼_／)
#  ٩(◍•౪•◍)۶✧˖°

# %%
print ("Hello \t Python")
# Out:
# Hello 	 Python

# %%
print ("Hello \n Python")
# Out:
# Hello
#  Python

# %%
print (" Hello \a Python")
# Out:
#  Hello  Python

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('Python\'s World')
# Out:
# Python's World

# %%
name="XYZ"
marks=84.789
age=22
print ("My name is",name,"my marks are",marks, "and my age is",age)
# Out:
# My name is XYZ my marks are 84.789 and my age is 22

# %%
print("My name is %s, my marks are %f and my age is %d" %(name,marks,age))
# Out:
# My name is XYZ, my marks are 84.789000 and my age is 22

# %%
print(f"My name is {name}, my marks are {marks} and my age is {age}")
# Out:
# My name is XYZ, my marks are 84.789 and my age is 22

# %%
print("My name is %4s, my marks are %4.2f and my age is %d" %(name,marks,age))
# Out:
# My name is  XYZ, my marks are 84.79 and my age is 22

# %%
a=70
id(a)
# Out:
# 10916704

# %%
_a=70
id(_a)
# Out:
# 10916704

# %%
del a

# %%
id(_a)
# Out:
# 10916704

# %%
256**0.5
# Out:
# 16.0

# %%
81/2
# Out:
# 40.5

# %%
81//4
# Out:
# 20

# %%
6785%2
# Out:
# 1

# %%
a=456
b=34
a==b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
c=34
c<b
# Out:
# False

# %%
c<=b
# Out:
# True

# %%
c!=b
# Out:
# False

# %%
a=240
bin(a)
# Out:
# '0b11110000'

# %%
b=1
bin(1)
# Out:
# '0b1'

# %%
a|b
# Out:
# 241

# %%
a & b
# Out:
# 0

# %%
a=45
b=76
c=900
a>b or a>c
a>b or a<c
# Out:
# True

# %%
3<89 & 900000>t
# Out:
# False

# %%
12>1
# Out:
# True

# %%
not 12>1
# Out:
# False

# %%
str1="thiruvananthapuram"
'z' in str1
# Out:
# False

# %%
'a' in str1
# Out:
# True
